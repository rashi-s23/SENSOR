# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score
df=pd.read_csv('/content/test.csv')
data=pd.read_csv('/content/train.csv')
df.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  ...  angle(Z,gravityMean)  subject  Activity
# 0           0.257178          -0.023285          -0.014654  ...             -0.057978        2  STANDING
# 1           0.286027          -0.013163          -0.119083  ...             -0.083898        2  STANDING
# 2           0.275485          -0.026050          -0.118152  ...             -0.079346        2  STANDING
# 3           0.270298          -0.032614          -0.117520  ...             -0.077108        2  STANDING
# 4           0.274833          -0.027848          -0.129527  ...             -0.073857        2  STANDING
#
# [5 rows x 563 columns]

# %%
x=df.iloc[0:-1].values
y=data.iloc[0:-1].values
print(x)
print(y)
# Out:
# [[0.25717778 -0.02328523 -0.014653762 ... -0.057978304 2 'STANDING']
#  [0.28602671 -0.013163359 -0.11908252 ... -0.083898014 2 'STANDING']
#  [0.27548482 -0.02605042 -0.11815167 ... -0.079346197 2 'STANDING']
#  ...
#  [0.36338465 -0.039214016 -0.10591509 ... 0.18241215 24
#   'WALKING_UPSTAIRS']
#  [0.34996609 0.030077442 -0.11578796 ... 0.18118355 24 'WALKING_UPSTAIRS']
#  [0.23759383 0.01846687 -0.096498932 ... 0.18756291 24 'WALKING_UPSTAIRS']]
# [[0.28858451 -0.020294171 -0.13290514 ... -0.058626924 1 'STANDING']
#  [0.27841883 -0.016410568 -0.12352019 ... -0.054316717 1 'STANDING']
#  [0.27965306 -0.019467156 -0.11346169 ... -0.049117815 1 'STANDING']
#  ...
#  [0.27385271 -0.0077493259 -0.14746837 ... 0.050052558 30
#   'WALKING_UPSTAIRS']
#  [0.27338737 -0.017010616 -0.045021828 ... 0.040811188 30
#   'WALKING_UPSTAIRS']
#  [0.28965416 -0.018843044 -0.15828059 ... 0.025339478 30
#   'WALKING_UPSTAIRS']]

# %%
x_train,x_test=train_test_split(x)
y_train,y_test=train_test_split(y)
print(x_train)
print(x_test)
print(y_train)
print(y_test)
# Out:
# [[0.22274976 -0.021824763 -0.09848602 ... -0.59294746 12 'LAYING']
#  [0.24244829 0.0062265257 -0.11724025 ... 0.02425099 9 'WALKING']
#  [0.28027188 -0.0097526255 -0.10100358 ... -0.037547868 18 'STANDING']
#  ...
#  [0.29926682 0.011798517 -0.031653276 ... -0.0051761577 2 'STANDING']
#  [0.4267814 -0.0050735172 -0.17990842 ... 0.0031097657 10
#   'WALKING_UPSTAIRS']
#  [0.27321662 -0.017481753 -0.1127654 ... -0.19941368 10 'LAYING']]
# [[0.19060765 -0.038960658 -0.1069849 ... 0.0078957265 20 'WALKING']
#  [0.27944941 -0.013646331 -0.13010446 ... 0.021580457 12 'STANDING']
#  [0.2777707 -0.01893374 -0.10246806 ... -0.019586902 20 'SITTING']
#  ...
#  [0.27801964 -0.017597684 -0.1068787 ... -0.24776596 18 'LAYING']
#  [0.13756918 -0.052284355 -0.15425046 ... -0.0079285947 20
#   'WALKING_DOWNSTAIRS']
#  [0.27714931 0.0037089737 -0.11374186 ... 0.12539878 24 'WALKING']]
# [[0.27777234 -0.021126584 -0.11154307 ... 0.06518289 30 'STANDING']
#  [0.27492413 -0.026888226 -0.14839094 ... 0.1305274 16 'STANDING']
#  [0.27310142 -0.035169084 -0.099076251 ... 0.14049034 23 'WALKING']
#  ...
#  [0.22783383 0.0046816022 -0.13100462 ... 0.12545291 16 'WALKING']
#  [0.27859164 -0.016939337 -0.11012823 ... -0.028862132 27 'SITTING']
#  [0.27329101 -0.010077946 -0.092243213 ... 0.015588611 25 'SITTING']]
# [[0.2771858 -0.017542121 -0.10567674 ... -0.11704086 26 'SITTING']
#  [0.38351111 -0.028943193 -0.11210642 ... 0.14511695 23
#   'WALKING_DOWNSTAIRS']
#  [0.2743814 -0.014031104 -0.10105394 ... -0.13756415 11 'STANDING']
#  ...
#  [0.25025528 0.0077234474 -0.058462756 ... 0.055110737 1
#   'WALKING_UPSTAIRS']
#  [0.27434638 -0.01737258 -0.10975475 ... -0.71429916 27 'LAYING']
#  [0.27254371 -0.01845352 -0.10618276 ... -0.75553459 23 'LAYING']]

# %%
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)
print(y_pred)
